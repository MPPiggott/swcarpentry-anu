# %%
import pandas as pd

# %%
surveys_df = pd.read_csv('surveys.csv')

# %%
surveys_df
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
surveys_df.species_id
# Out:
# 0         NL
# 1         NL
# 2         DM
# 3         DM
# 4         DM
# 5         PF
# 6         PE
# 7         DM
# 8         DM
# 9         PF
# 10        DS
# 11        DM
# 12        DM
# 13        DM
# 14        DM
# 15        DM
# 16        DS
# 17        PP
# 18        PF
# 19        DS
# 20        DM
# 21        NL
# 22        DM
# 23        SH
# 24        DM
# 25        DM
# 26        DM
# 27        DM
# 28        PP
# 29        DS
#         ...
# 35519     SF
# 35520     DM
# 35521     DM
# 35522     DM
# 35523     PB
# 35524     OL
# 35525     OT
# 35526     DO
# 35527     US
# 35528     PB
# 35529     OT
# 35530     PB
# 35531     DM
# 35532     DM
# 35533     DM
# 35534     DM
# 35535     DM
# 35536     DM
# 35537     PB
# 35538     SF
# 35539     PB
# 35540     PB
# 35541     PB
# 35542     PB
# 35543     US
# 35544     AH
# 35545     AH
# 35546     RM
# 35547     DO
# 35548    NaN
# Name: species_id, dtype: object

# %%
surveys_species = surveys_df['species_id']
surveys_species.head()
# Out:
# 0    NL
# 1    NL
# 2    DM
# 3    DM
# 4    DM
# Name: species_id, dtype: object

# %%
surveys_df[['species_id', 'plot_id']].head()
# Out:
#   species_id  plot_id
# 0         NL        2
# 1         NL        3
# 2         DM        2
# 3         DM        7
# 4         DM        3

# %%
surveys_df['species_id'].head()
# Out:
# 0    NL
# 1    NL
# 2    DM
# 3    DM
# 4    DM
# Name: species_id, dtype: object

# %%
nums = [1,2,3,4,5]

# %%
surveys_df[0:3]
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN

# %%
#index by row then column
surveys_df.iloc[0:3, 3:9]
# Out:
#    year  plot_id species_id sex  hindfoot_length  weight
# 0  1977        2         NL   M             32.0     NaN
# 1  1977        3         NL   M             33.0     NaN
# 2  1977        2         DM   F             37.0     NaN

# %%
surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
# select all columns for rows of index values 0 and 10
surveys_df.loc[[0, 10], :]
# Out:
#     record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0           1      7   16  1977        2         NL   M             32.0
# 10         11      7   16  1977        5         DS   F             53.0
#
#     weight
# 0      NaN
# 10     NaN

# %%
# what does this do?
surveys_df.loc[0, ['species_id', 'plot_id', 'weight']]
# Out:
# species_id     NL
# plot_id         2
# weight        NaN
# Name: 0, dtype: object

# %%
# What happens when you type the code below?
surveys_df.loc[[0, 10, 35549], :]
# Out:
#        record_id  month   day    year  plot_id species_id  sex  \
# 0            1.0    7.0  16.0  1977.0      2.0         NL    M
# 10          11.0    7.0  16.0  1977.0      5.0         DS    F
# 35549        NaN    NaN   NaN     NaN      NaN        NaN  NaN
#
#        hindfoot_length  weight
# 0                 32.0     NaN
# 10                53.0     NaN
# 35549              NaN     NaN

# %%
surveys_df.iloc[2,6]
# Out:
# 'F'

# %%
type(surveys_df.iloc[2,6])
# Out:
# str

# %%
surveys_df[0:3]
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN

# %%
surveys_df[surveys_df.year == 2002].head()
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 33320      33321      1   12  2002        1         DM    M             38.0
# 33321      33322      1   12  2002        1         DO    M             37.0
# 33322      33323      1   12  2002        1         PB    M             28.0
# 33323      33324      1   12  2002        1         AB  NaN              NaN
# 33324      33325      1   12  2002        1         DO    M             35.0
#
#        weight
# 33320    44.0
# 33321    58.0
# 33322    45.0
# 33323     NaN
# 33324    29.0

# %%
surveys_df.iloc[0:4, 1:4]
# Out:
#    month  day  year
# 0      7   16  1977
# 1      7   16  1977
# 2      7   16  1977
# 3      7   16  1977

# %%
surveys_df.loc[0:4, 1:4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-3d4447deef2e> in <module>()
# ----> 1 surveys_df.loc[0:4, 1:4]
#
# /Users/u4468625/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1282     def __getitem__(self, key):
#    1283         if type(key) is tuple:
# -> 1284             return self._getitem_tuple(key)
#    1285         else:
#    1286             return self._getitem_axis(key, axis=0)
#
# /Users/u4468625/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     798                 continue
#     799
# --> 800             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     801
#     802         return retval
#
# /Users/u4468625/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
# ...

# %%
surveys_df[surveys_df.year != 2002]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
surveys_df[(surveys_df.year >= 1980) & (surveys_df.year <= 1985)]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 2270        2271      1   15  1980        8         DO    M             35.0
# 2271        2272      1   15  1980       11         PF    F             16.0
# 2272        2273      1   15  1980       18         DM    F             34.0
# 2273        2274      1   15  1980       11         DM    M             38.0
# 2274        2275      1   15  1980        8         DO    F             33.0
# 2275        2276      1   15  1980       11         DS    M             47.0
# 2276        2277      1   15  1980        8         PF    M             15.0
# 2277        2278      1   15  1980        9         OT    M             21.0
# 2278        2279      1   15  1980       11         DM    F             36.0
# 2279        2280      1   15  1980       21         OT    F             20.0
# 2280        2281      1   15  1980       11         OL    M             20.0
# ...

# %%
surveys_df[(surveys_df.year == 1999) & (surveys_df.weight <= 8)]
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 29082      29083      1   16  1999       21         RM   M             16.0
# 29196      29197      2   20  1999       18         RM   M             18.0
# 29421      29422      3   15  1999       16         RM   M             15.0
# 29903      29904     10   10  1999        4         PP   M             20.0
# 29905      29906     10   10  1999        4         PP   M             21.0
#
#        weight
# 29082     8.0
# 29196     8.0
# 29421     8.0
# 29903     7.0
# 29905     4.0

# %%
surveys_df[surveys_df['species_id'].isin(['RM', 'PP'])]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 17            18      7   16  1977        2         PP    M             22.0
# 28            29      7   17  1977       11         PP    M              NaN
# 48            49      7   18  1977       12         PP    F             17.0
# 88            89      8   20  1977       12         PP    F             20.0
# 107          108      8   20  1977       11         PP    M             21.0
# 162          163      9   11  1977       12         PP    F             21.0
# 216          217      9   13  1977        3         PP    F             19.0
# 310          311     10   17  1977       19         RM    M             18.0
# 396          397     11   13  1977       17         RM    F             16.0
# 694          695      3   12  1978       17         RM  NaN              NaN
# 896          897      5   18  1978       11         PP    M             21.0
# ...

# %%
surveys_df[(surveys_df.weight == 90)]
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 782          783      4    9  1978       14         DS   F             47.0
# 845          846      5    6  1978        9         DS   F              NaN
# 854          855      5    6  1978        9         DS   F              NaN
# 930          931      5   19  1978        9         DS   F             46.0
# 936          937      6    8  1978       12         DS   M              NaN
# 2811        2812      3   22  1980       13         DS   M             47.0
# 3082        3083      6   23  1980        2         DS   F             51.0
# 3124        3125      7   21  1980       18         DS   M             47.0
# 4164        4165      4    5  1981       22         DS   F             47.0
# 4523        4524      6    4  1981        9         DS   F             50.0
# 4669        4670      7    8  1981        6         DS   F             50.0
# ...

# %%
surveys_df[~(surveys_df['sex'].isin(['M']))
           & surveys
# Out:
#   File "<ipython-input-60-cf0abaa2c82a>", line 1
#     surveys_df[~(surveys_df['sex'].isin(['M']))
#                                                ^
# SyntaxError: unexpected EOF while parsing

# %%
surveys_df[(surveys_df.year >= 1980)
           & (surveys_df.year <= 1985)
           & ~(surveys_df['species_id'].isnull())
          ].tail()
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 11221      11222     12    8  1985        7         AB  NaN              NaN
# 11222      11223     12    8  1985        4         DM    M             36.0
# 11223      11224     12    8  1985       11         DM    M             37.0
# 11224      11225     12    8  1985        7         PE    M             20.0
# 11225      11226     12    8  1985        1         DM    M             38.0
#
#        weight
# 11221     NaN
# 11222    40.0
# 11223    49.0
# 11224    18.0
# 11225    47.0

# %%
surveys_df['species_id'].isnull().head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: species_id, dtype: bool

# %%
pd.isnull(surveys_df)
# Out:
#       record_id  month    day   year plot_id species_id    sex  \
# 0         False  False  False  False   False      False  False
# 1         False  False  False  False   False      False  False
# 2         False  False  False  False   False      False  False
# 3         False  False  False  False   False      False  False
# 4         False  False  False  False   False      False  False
# 5         False  False  False  False   False      False  False
# 6         False  False  False  False   False      False  False
# 7         False  False  False  False   False      False  False
# 8         False  False  False  False   False      False  False
# 9         False  False  False  False   False      False  False
# 10        False  False  False  False   False      False  False
# 11        False  False  False  False   False      False  False
# 12        False  False  False  False   False      False  False
# 13        False  False  False  False   False      False   True
# ...

# %%
surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
#To select just the rows with NaN values, we can use the .any method
surveys_df[~(pd.isnull(surveys_df).any(axis=1))]
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 62            63      8   19  1977        3         DM   M             35.0
# 63            64      8   19  1977        7         DM   M             37.0
# 64            65      8   19  1977        4         DM   F             34.0
# 65            66      8   19  1977        4         DM   F             35.0
# 66            67      8   19  1977        7         DM   M             35.0
# 67            68      8   19  1977        8         DO   F             32.0
# 68            69      8   19  1977        2         PF   M             15.0
# 69            70      8   19  1977        3         OX   F             21.0
# 70            71      8   19  1977        7         DM   F             36.0
# 73            74      8   19  1977        8         PF   M             12.0
# 74            75      8   19  1977        8         DM   F             32.0
# ...

# %%
# what does this do?
emptyWeights = surveys_df[pd.isnull(surveys_df).any(axis=1)]['weight']

# %%
surveys_df[(surveys_df['sex'].isin(['M']))
           & surveys_df['sex'].isin(['F'])
           & (surveys_df['weight'] > 0)]
# Out:
# Empty DataFrame
# Columns: [record_id, month, day, year, plot_id, species_id, sex, hindfoot_length, weight]
# Index: []

# %%
sex_df = surveys_df[surveys_df['sex'].isin(['M', 'F'])
          & (surveys_df.weight >0)]

# %%
# %matplotlib inline

# %%
sex_df
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 62            63      8   19  1977        3         DM   M             35.0
# 63            64      8   19  1977        7         DM   M             37.0
# 64            65      8   19  1977        4         DM   F             34.0
# 65            66      8   19  1977        4         DM   F             35.0
# 66            67      8   19  1977        7         DM   M             35.0
# 67            68      8   19  1977        8         DO   F             32.0
# 68            69      8   19  1977        2         PF   M             15.0
# 69            70      8   19  1977        3         OX   F             21.0
# 70            71      8   19  1977        7         DM   F             36.0
# 73            74      8   19  1977        8         PF   M             12.0
# 74            75      8   19  1977        8         DM   F             32.0
# ...

# %%
surveys_df = pd.read_csv("surveys.csv")

# %%
surveys_df
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
species_df = pd.read_csv('species.csv')

# %%
species_df
# Out:
#    species_id             genus          species     taxa
# 0          AB        Amphispiza        bilineata     Bird
# 1          AH  Ammospermophilus          harrisi   Rodent
# 2          AS        Ammodramus       savannarum     Bird
# 3          BA           Baiomys          taylori   Rodent
# 4          CB   Campylorhynchus  brunneicapillus     Bird
# 5          CM       Calamospiza      melanocorys     Bird
# 6          CQ        Callipepla         squamata     Bird
# 7          CS          Crotalus       scutalatus  Reptile
# 8          CT     Cnemidophorus           tigris  Reptile
# 9          CU     Cnemidophorus        uniparens  Reptile
# 10         CV          Crotalus          viridis  Reptile
# 11         DM         Dipodomys         merriami   Rodent
# 12         DO         Dipodomys            ordii   Rodent
# 13         DS         Dipodomys      spectabilis   Rodent
# 14         DX         Dipodomys              sp.   Rodent
# ...

# %%
#read in first 10 lines of surveys table
surveySub = surveys_df.head(10)

# %%
surveySub
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN

# %%
# grab the last 10 rows (minus the last one)
surveySubLast10 = surveys_df[-11:-1]

# %%
surveySubLast10
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35538      35539     12   31  2002       15         SF    M             26.0
# 35539      35540     12   31  2002       15         PB    F             26.0
# 35540      35541     12   31  2002       15         PB    F             24.0
# 35541      35542     12   31  2002       15         PB    F             26.0
# 35542      35543     12   31  2002       15         PB    F             27.0
# 35543      35544     12   31  2002       15         US  NaN              NaN
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
#
#        weight
# 35538    68.0
# 35539    23.0
# 35540    31.0
# 35541    29.0
# 35542    34.0
# 35543     NaN
# ...

# %%
#reset the index values to the second dataframe appends properly
surveySubLast10=surveySubLast10.reset_index(drop=True)

# %%
# drop=True option avoids adding new index column with old index values
surveySubLast10
# Out:
#    record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0      35539     12   31  2002       15         SF    M             26.0
# 1      35540     12   31  2002       15         PB    F             26.0
# 2      35541     12   31  2002       15         PB    F             24.0
# 3      35542     12   31  2002       15         PB    F             26.0
# 4      35543     12   31  2002       15         PB    F             27.0
# 5      35544     12   31  2002       15         US  NaN              NaN
# 6      35545     12   31  2002       15         AH  NaN              NaN
# 7      35546     12   31  2002       15         AH  NaN              NaN
# 8      35547     12   31  2002       10         RM    F             15.0
# 9      35548     12   31  2002        7         DO    M             36.0
#
#    weight
# 0    68.0
# 1    23.0
# 2    31.0
# 3    29.0
# 4    34.0
# 5     NaN
# 6     NaN
# 7     NaN
# 8    14.0
# 9    51.0

# %%
#stack the DataFrames on top of each other
verticalStack = pd.concat([surveySub, surveySubLast10], axis=0)

# %%
verticalStack
# Out:
#    record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL    M             32.0
# 1          2      7   16  1977        3         NL    M             33.0
# 2          3      7   16  1977        2         DM    F             37.0
# 3          4      7   16  1977        7         DM    M             36.0
# 4          5      7   16  1977        3         DM    M             35.0
# 5          6      7   16  1977        1         PF    M             14.0
# 6          7      7   16  1977        2         PE    F              NaN
# 7          8      7   16  1977        1         DM    M             37.0
# 8          9      7   16  1977        1         DM    F             34.0
# 9         10      7   16  1977        6         PF    F             20.0
# 0      35539     12   31  2002       15         SF    M             26.0
# 1      35540     12   31  2002       15         PB    F             26.0
# ...

# %%
# place the DataFrames side by side
horizontalStack = pd.concat([surveySub, surveySubLast10], axis=1)

# %%
horizontalStack
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight  record_id  month  day  year  plot_id species_id  sex  \
# 0     NaN      35539     12   31  2002       15         SF    M
# ...

# %%
# Write DataFrame to CSV 
verticalStack.to_csv('out.csv')

# %%
surveys1980 = surveys_df[surveys_df['year'] == 1980]

# %%
surveys1980
# Out:
#       record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 2270       2271      1   15  1980        8         DO    M             35.0
# 2271       2272      1   15  1980       11         PF    F             16.0
# 2272       2273      1   15  1980       18         DM    F             34.0
# 2273       2274      1   15  1980       11         DM    M             38.0
# 2274       2275      1   15  1980        8         DO    F             33.0
# 2275       2276      1   15  1980       11         DS    M             47.0
# 2276       2277      1   15  1980        8         PF    M             15.0
# 2277       2278      1   15  1980        9         OT    M             21.0
# 2278       2279      1   15  1980       11         DM    F             36.0
# 2279       2280      1   15  1980       21         OT    F             20.0
# 2280       2281      1   15  1980       11         OL    M             20.0
# ...

# %%
surveys1982 = surveys_df[surveys_df['year'] == 1982]

# %%
surveys1982
# Out:
#       record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 5157       5158      1    1  1982        1         DO   F             37.0
# 5158       5159      1    1  1982        5         DM   F             34.0
# 5159       5160      1    1  1982        3         RM   F             16.0
# 5160       5161      1    1  1982        5         NL   F             33.0
# 5161       5162      1    1  1982        3         RM   F             17.0
# 5162       5163      1    1  1982        3         NL   F             34.0
# 5163       5164      1    1  1982        2         DS   F             49.0
# 5164       5165      1    1  1982        3         PF   M             15.0
# 5165       5166      1    1  1982        4         DM   M             36.0
# 5166       5167      1    1  1982        2         DM   M             35.0
# 5167       5168      1    1  1982        4         DS   M             52.0
# ...

# %%
verticalStack = pd.concat([surveys1980, surveys1982], axis=0)

# %%
verticalStack.to_csv('out1.csv')

# %%
surveySub = surveys_df.head(10)

# %%
surveySub.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
species_df.columns
# Out:
# Index(['species_id', 'genus', 'species', 'taxa'], dtype='object')

# %%
merged_inner = pd.merge(left=species_df, right=surveySub, left_on='species_id', right_on='species_id')
merged_inner
# Out:
#   species_id        genus   species    taxa  record_id  month  day  year  \
# 0         DM    Dipodomys  merriami  Rodent          3      7   16  1977
# 1         DM    Dipodomys  merriami  Rodent          4      7   16  1977
# 2         DM    Dipodomys  merriami  Rodent          5      7   16  1977
# 3         DM    Dipodomys  merriami  Rodent          8      7   16  1977
# 4         DM    Dipodomys  merriami  Rodent          9      7   16  1977
# 5         NL      Neotoma  albigula  Rodent          1      7   16  1977
# 6         NL      Neotoma  albigula  Rodent          2      7   16  1977
# 7         PE   Peromyscus  eremicus  Rodent          7      7   16  1977
# 8         PF  Perognathus    flavus  Rodent          6      7   16  1977
# 9         PF  Perognathus    flavus  Rodent         10      7   16  1977
#
#    plot_id sex  hindfoot_length  weight
# 0        2   F             37.0     NaN
# 1        7   M             36.0     NaN
# 2        3   M             35.0     NaN
# ...

# %%
# in this case `species_id` is the only column name in  both dataframes, so if we skippd `left_on`
# and `right_on` arguments we would still get the same result
merged_left = pd.merge(left=surveySub,right=species_df, how='left', left_on='species_id', right_on='species_id')

# %%
merged_left
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight        genus   species    taxa
# 0     NaN      Neotoma  albigula  Rodent
# 1     NaN      Neotoma  albigula  Rodent
# 2     NaN    Dipodomys  merriami  Rodent
# ...

# %%
merged_inner = pd.merge(left=species_df, right=surveys_df, left_on='species_id', right_on='species_id')
merged_inner
# Out:
#       species_id        genus     species     taxa  record_id  month  day  \
# 0             AB   Amphispiza   bilineata     Bird       3126      7   21
# 1             AB   Amphispiza   bilineata     Bird       3146      7   21
# 2             AB   Amphispiza   bilineata     Bird       3152      7   21
# 3             AB   Amphispiza   bilineata     Bird       3153      7   21
# 4             AB   Amphispiza   bilineata     Bird       3586     12   15
# 5             AB   Amphispiza   bilineata     Bird       3702      1   11
# 6             AB   Amphispiza   bilineata     Bird       3705      1   11
# 7             AB   Amphispiza   bilineata     Bird       3706      1   11
# 8             AB   Amphispiza   bilineata     Bird       3775      1   12
# 9             AB   Amphispiza   bilineata     Bird       4499      6    4
# 10            AB   Amphispiza   bilineata     Bird       4543      6    4
# 11            AB   Amphispiza   bilineata     Bird       4606      7    7
# ...

# %%
merged_inner['weight'].describe()
# Out:
# count    32283.000000
# mean        42.672428
# std         36.631259
# min          4.000000
# 25%         20.000000
# 50%         37.000000
# 75%         48.000000
# max        280.000000
# Name: weight, dtype: float64

# %%
merged_inner['hindfoot_length'].describe()
# Out:
# count    31438.000000
# mean        29.287932
# std          9.564759
# min          2.000000
# 25%         21.000000
# 50%         32.000000
# 75%         36.000000
# max         70.000000
# Name: hindfoot_length, dtype: float64

# %%
sorted = merged_inner.groupby('taxa')
sorted.describe()
# Out:
#                         day  hindfoot_length         month       plot_id  \
# taxa
# Bird    count    450.000000         0.000000    450.000000    450.000000
#         mean      16.088889              NaN      5.491111     13.886667
#         std        8.684323              NaN      3.981154      6.712887
#         min        1.000000              NaN      1.000000      1.000000
#         25%        8.250000              NaN      2.000000      8.250000
#         50%       15.000000              NaN      4.000000     13.000000
#         75%       24.000000              NaN      9.000000     20.000000
#         max       31.000000              NaN     12.000000     24.000000
# Rabbit  count     75.000000         0.000000     75.000000     75.000000
#         mean      15.440000              NaN      5.786667     13.693333
#         std        9.749900              NaN      1.869335      6.428344
#         min        1.000000              NaN      3.000000      1.000000
# ...

# %%
taxa_counts = merged_inner.groupby('taxa')['plot_id'].count()

# %%
taxa_counts
# Out:
# taxa
# Bird         450
# Rabbit        75
# Reptile       14
# Rodent     34247
# Name: plot_id, dtype: int64

# %%
taxa_counts.plot(kind='bar');

# %%
sorted = merged_inner.groupby('species_id')['genus'].count().plot(kind='bar')

# %%
import sys
import pandas as pd

def main():
        filename = 'surveys.csv'
        year = '1982'
        factor = 'sex'
        weight = 'weight'

        year = int(year)
        print(filename, year, factor)
        survey_df = pd.read_csv(filename)
        sub_year = survey_df
        grouping_df = factor.weight
        mean_by_group = grouping_df.mean()
        
        print(mean_by_group)
